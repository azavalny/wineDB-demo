# %%
import pandas as pd

vineyards = pd.read_csv('vineyard.csv')
vineyards.head()
# Out:
#    Unnamed: 0  vineyard_id             name  \
# 0           0            0          Nicosia
# 1           1            1       St. Julian
# 2           2            2     Sweet Cheeks
# 3           3            3           Tandem
# 4           4            4  Terre di Giurfo
#
#                            appelation country               region
# 0                        Vulkà Bianco   Italy                 Etna
# 1                Reserve Late Harvest      US  Lake Michigan Shore
# 2  Vintner's Reserve Wild Child Block      US    Willamette Valley
# 3                        Ars In Vitro   Spain              Navarra
# 4                             Belsito   Italy             Vittoria

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import time
import json

def scrape_cellar_tracker_search(urls):
    chrome_options = Options()
    # chrome_options.add_argument("--headless")
    chrome_options.add_argument("--disable-gpu")
    chrome_options.add_argument("--no-sandbox")
    
    driver = webdriver.Chrome(options=chrome_options)

    wine_list = []

    for url, appelation in urls:
        
        driver.get(url)

        time.sleep(10)
        
        # Get page source after JS rendering
        html = driver.page_source
        
        # Parse HTML with BeautifulSoup
        soup = BeautifulSoup(html, "html.parser")
        table = soup.find("table", {"id": "main_table"})
        
        # Parse each table row
        try:
            for row in table.find_all("tr")[1:]:
                cols = row.find_all("td")
                if len(cols) < 2:
                    continue
            
                wine_type = cols[0].get_text(strip=True)
            
                name_block = cols[1]
                name = name_block.find("h3").get_text(strip=True)
                loc = name_block.find("span", class_="el loc").get_text(strip=True)
            
                qty = cols[2].find("span", class_="el gty")
                quantity = qty.get_text(strip=True) if qty else ""
            
                score_span = cols[3].find("span", class_="el scr")
                score = score_span.get_text(strip=True) if score_span else ""

                scraped_wine = {
                    "type": wine_type,
                    "name": name,
                    "location": loc,
                    "appelation":appelation,
                    "quantity": quantity,
                    "score": score
                }
                wine_list.append(scraped_wine)
                with open("wines.json", 'r') as f:
                    existing_data = json.load(f)
                existing_data.append(scraped_wine)
                with open("wines.json", "w") as json_file:
                    json.dump(existing_data, json_file)
        except AttributeError:
            continue
    driver.quit()
    return wine_list

# %%
searches = []
for index, row in vineyards.iterrows():
    toSearch = "+".join([row["name"], row["region"], row["appelation"], row["country"]])
    searches.append(["https://www.cellartracker.com/list.asp?fInStock=0&iUserOverride=0&Table=List&szSearch=" + toSearch, row["appelation"]])

# %%
wines = scrape_cellar_tracker_search(searches[200:300])

# %%
with open("wines.json", "r") as f:
    wines = json.load(f)

# %%
wines = pd.DataFrame(wines)
wines.rename(columns={"type":"classification", "score":"rating"}, inplace=True)

# %%
wines["year"] = wines["name"].str[:4]

# %%
wines.drop("quantity", inplace=True, axis=1)

# %%
wines['rating_out_of_5'] = (
    wines['rating']
    .str.extract(r'(\d+)')        # Extract digits
    .astype(float)                # Convert to float (NaN if no digits)
    .div(20)                      # Scale to 5-star rating
)

# %%
wines.drop("rating", inplace=True, axis=1)

# %%
wines.rename(columns={"rating_out_of_5":"rating"}, inplace=True)

# %%
wines
# Out:
#      classification                                               name  \
# 0             White             2014 Cantine Nicosia Etna Vulka Bianco
# 1             White             2023 Cantine Nicosia Etna Vulka Bianco
# 2             White             2022 Cantine Nicosia Etna Vulka Bianco
# 3             White             2021 Cantine Nicosia Etna Vulka Bianco
# 4             White             2020 Cantine Nicosia Etna Vulka Bianco
# ...             ...                                                ...
# 1777          White  2018 Raptor Ridge Grüner Veltliner Tuscowallam...
# 1778          White  2017 Raptor Ridge Grüner Veltliner Tuscowallam...
# 1779          White  2016 Raptor Ridge Grüner Veltliner Tuscowallam...
# 1780            Red                2021 Raptor Ridge Pinot Noir Estate
# 1781            Red                2020 Raptor Ridge Pinot Noir Estate
#
#                 location    appelation  year  rating
# 0               Etna DOC  Vulkà Bianco  2014    4.50
# 1               Etna DOC  Vulkà Bianco  2023     NaN
# 2               Etna DOC  Vulkà Bianco  2022    4.50
# 3               Etna DOC  Vulkà Bianco  2021    4.30
# 4               Etna DOC  Vulkà Bianco  2020     NaN
# ...                  ...           ...   ...     ...
# 1777  Chehalem Mountains        Estate  2018    4.25
# 1778  Chehalem Mountains        Estate  2017     NaN
# 1779  Chehalem Mountains        Estate  2016     NaN
# 1780  Chehalem Mountains        Estate  2021     NaN
# 1781  Chehalem Mountains        Estate  2020     NaN
#
# [1782 rows x 6 columns]

# %%
wines.to_csv("wines.csv")

# %%
wines["name_short"] = wines["name"].str[5:]

wines.drop("name", inplace=True, axis=1)

# %%
wines.drop("Unnamed: 0", axis=1, inplace=True)

# %%
wines.rename(columns={"name_short":"name"}, inplace=True)

# %%
wines.to_csv("wines.csv")

# %%
import pandas as pd

wines = pd.read_csv("wine.csv")

# %%
from openai import OpenAI
client = OpenAI(api_key="")

food_pairings = []
i=0
for name in wines["name"].unique():
    response = client.responses.create(
        model="gpt-4o-mini",
        input=f'Give me the name of the best food pairing that goes with this wine:{name}\n\nOnly return a 1-5 word name of a food without punctuation'
    )
    result = response.output_text
    print(result)
    i+=1
    food_pairings.append({"wine_id":i, "name":result})
# Out:
# Grilled seafood platter
# Crème brûlée
# Spicy Thai curry
# Blue cheese tart
# Goat cheese tart
# Blue cheese platter
# Blue cheese platter
# Blue cheese
# Blue cheese tart
# Grilled lamb chops
# Grilled lamb chops
# Grilled lamb chops
# Grilled lamb chops
# Grilled lamb chops
# Grilled steak
# Grilled lamb chops
# Grilled lamb chops
# Grilled lamb chops
# Grilled ribeye steak
# Roasted duck breast
# Grilled lamb chops
# Grilled steak
# Grilled lamb chops
# Grilled seafood salad
# Grilled lamb chops
# Grilled lamb skewers
# Duck confit
# Grilled seafood platter
# Grilled lamb chops
# Grilled salmon salad
# Braised short ribs
# Beef tenderloin
# Grilled lamb chops
# Grilled ribeye steak
# Beef Wellington
# Grilled lamb chops
# Grilled lamb chops
# Grilled lamb chops
# Grilled salmon salad
# Grilled lemon herb chicken
# Spicy Asian cuisine
# Grilled seafood platter
# Braised lamb shanks
# Braised short ribs
# Spicy Thai curry
# Roasted duck breast
# Braised lamb shanks
# Grilled lamb chops
# Grilled seafood salad
# Herb roasted chicken
# Herb crusted lamb chops
# Grilled salmon salad
# Grilled ribeye steak
# Grilled lamb chops
# Grilled ribeye steak
# Roasted lamb shanks
# Grilled ribeye steak
# Grilled ribeye steak
# Grilled shrimp tacos
# Grilled ribeye steak
# Grilled salmon
# Roasted Duck Breast
# Grilled lamb chops
# Bistecca alla Fiorentina
# Bistecca alla Fiorentina
# Charcuterie board
# Barbecue ribs
# Oysters on the half shell
# Oysters on the half shell
# Chocolate covered strawberries
# Fresh oysters
# Grilled steak
# Lemon butter scallops
# Grilled ribeye steak
# Grilled lamb chops
# Braised lamb shanks
# Grilled lemon herb chicken
# Grilled lamb skewers
# Lamb tagine
# Grilled lemon herb chicken
# Lemon butter scallops
# Grilled lamb chops
# Grilled prawns with lemon
# Grilled lamb skewers
# Grilled seafood platter
# Grilled Herb Chicken
# Salmon sushi
# Oysters on the half shell
# Grilled sea bass
# Duck breast with cherry sauce
# Wild mushroom risotto
# Duck confit
# Roasted duck breast
# Grilled salmon
# Duck confit
# Grilled salmon with herbs
# Grilled lamb chops
# Grilled lamb chops
# Grilled lemon herb chicken
# Grilled lamb chops
# Grilled lamb chops
# Grilled lamb chops
# Herb roasted chicken
# Grilled salmon
# Blue cheese and honey
# Duck confit
# Spicy Thai Curry
# Roast duck with cherries
# Grilled red meat
# Grilled lamb chops
# Grilled lamb chops
# Herb roasted chicken
# Duck confit
# Duck confit
# Herb roasted chicken
# Duck confit
# Grilled salmon
# Grilled lamb chops
# Grilled ribeye steak
# Grilled asparagus salad
# Grilled lamb chops
# Smoked brisket
# Lamb shoulder roast
# Lobster with lemon butter
# Seared scallops with lemon beurre blanc
# Duck confit salad
# Truffle risotto
# Spicy Thai Curry
# Grilled lamb chops
# Roasted duck breast
# Grilled lamb chops
# Grilled seafood platter
# Roasted duck breast
# Grilled lamb chops
# Grilled seafood salad
# Grilled shrimp with lemon
# Spicy Asian Cuisine
# Spicy Thai Curry
# Lemon herb chicken
# Grilled lamb chops
# Grilled lamb chops
# Grilled salmon salad
# Grilled lemon herb chicken
# Grilled lemon herb chicken
# Grilled lamb chops
# Grilled lamb chops
# Grilled lamb chops
# Grilled salmon with citrus
# Grilled salmon
# Oysters on the half shell
# Grilled shrimp tacos
# Grilled salmon
# Grilled white fish
# Blue cheese platter
# Grilled lamb chops
# Spicy Thai Curry
# Grilled lemon herb chicken
# Seared scallops
# Grilled lamb chops
# Grilled lamb chops
# Grilled salmon salad
# Dark chocolate truffles
# Blue cheese profile
# Dark chocolate truffles
# Dark chocolate truffles
# Spiced pear tart
# Blue cheese tart
# Blue cheese and figs
# Blue cheese dessert
# Blue cheese pairing
# Oysters on the half shell
# Cheddar cheese platter
# Duck confit
# Lobster with lemon butter
# Grilled lamb chops
# Grilled lamb chops
# Filet mignon
# Mushroom risotto
# Roasted duck
# Grilled lamb chops
# Grilled ribeye steak
# Grilled lamb chops
# Roasted duck breast
# Grilled scallops
# Roasted lamb
# Grilled bratwurst sandwich
# Charcuterie board
# Grilled salmon with herbs
# Grilled salmon asparagus salad
# Grilled ribeye steak
# Grilled lamb chops
# Lobster bisque
# Duck confit
# Duck confit
# Roasted duck breast
# Grilled lamb chops
# Grilled ribeye steak
# Grilled steak
# Grilled salmon
# Duck confit
# Duck confit salad
# Roasted apricot tart
# Grilled lamb chops
# Lobster risotto
# Duck confit
# Mushroom risotto
# Oysters on the half shell
# Lobster risotto
# Duck confit
# Grilled lamb chops
# Grilled ribeye steak
# Grilled lemon herb chicken
# Grilled lamb chops
# Grilled salmon
# Grilled lamb chops
# Duck confit
# Grilled lamb chops
# Roasted chicken lemon herb
# Duck confit
# Herb crusted lamb
# Grilled lamb chops
# Grilled lamb chops
# Grilled ribeye steak
# Lobster risotto
# Lobster in butter sauce
# Grilled sea bass
# Grilled lamb kabobs
# Roasted Mushrooms
# Grilled salmon salad
# Roasted chicken with herbs
# Spicy Thai Curry
# Spiced Thai curry
# Grilled Scallops
# Grilled steak
# Grilled lamb chops
# Grilled lamb chops
# Mushroom risotto
# Grilled lamb chops
# Mushroom risotto
# Grilled lamb chops
# Oysters on the half shell
# Asparagus risotto
# Asparagus risotto
# Duck confit

# %%
pd.DataFrame(food_pairings).to_csv("food_pairings.csv")
